# %% [markdown]
# # Agenda
# - what is encapsulation
# - real world examples
# - Advantages
# - Public,private,protected
# - code

# %% [markdown]
# # What is encapsulation
# In simpler terms, encapsulation in Python is about grouping data and the methods that work on that data together, and restricting access to the internal details of the class.

# %% [markdown]
# # Real World Example
# # 1.Multivitamin
# ![encapsulation.png](attachment:encapsulation.png)
# # 2.  ATM:
# Data (encapsulated): Account balances, transaction history, security measures.
#
# Public methods: Withdraw cash, deposit cash, check balance, transfer funds.
#
# Benefits:
# - Users interact with a secure interface, protecting sensitive financial data.
# - Prevents unauthorized access to accounts or tampering with transactions.
# - Maintains integrity of financial data

# %% [markdown]
# ![fd](data:image/jpeg;base64,...)

# %% [markdown]
# # Advantages
#
# This helps in organizing code, enhancing code readability, and promoting the concept of information hiding.
#
# Data Hiding:
#
# Security

# %% [markdown]
# # Access modifiers

# %% [markdown]
# ### Public Member: Accessible anywhere from outside of class.
# ### Private Member: Accessible within the class
# ### Protected Member: Accessible within the class and its sub-classes

# %% [markdown]
# # Code

# %% [markdown]
# # syntax for this modifiers

# %%
# public= var
# privatemember= __var
# protected member= _var

# %%
class Example:
    def __init__(self):
        self.public='I am public member'
        self.__private='I am private member'
        self._protected='I am protected member'
        
obj=Example()

# %%
obj.public
# Out:
# 'I am public member'

# %%
# name mangling
obj._Example__private
# Out:
# 'I am private member'

# %%
obj._protected
# Out:
# 'I am protected member'

# %%
class Example:
    def __init__(self):
        self.public='I am public member'
        self.__private='I am private member'
        self._protected='I am protected member'
       #getter function 
    def getpub(self):    
        return self.public
    def getprivate(self):
        return self.__private
    def getprotected(self):
        return self._protected

# %%
obj1=Example()

# %%
obj1.getpub()
# Out:
# 'I am public member'

# %%
obj1.getprivate()
# Out:
# 'I am private member'

# %%
obj1.getprotected()
# Out:
# 'I am protected member'

# %%
class Example:
    def __init__(self):
        self.public='I am public member'
        self.__private='I am private member'
        self._protected='I am protected member'
       #getter function 
    def getpub(self):    
        return self.public
    def getprivate(self):
        return self.__private
    def getprotected(self):
        return self._protected
    #setter method
    def setpub(self,r):
        self.public=r
    def setprivate(self,g):
        self.__private=g
        
    def setprotected(self,b):
        self._protected=b

# %%
obj3=Example()

# %%
print(obj3.getpub())
print(obj3.getprivate())
print(obj3.getprotected())
# Out:
# I am public member
# I am private member
# I am protected member

# %%
obj3.setpub('New public')

# %%
obj3.setprivate('New Private')

# %%
obj3.setprotected('New protected')

# %%
print(obj3.getpub())
print(obj3.getprivate())
print(obj3.getprotected())
# Out:
# New public
# New Private
# New protected
