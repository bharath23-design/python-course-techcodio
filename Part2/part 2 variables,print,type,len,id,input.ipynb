# %% [markdown]
# # Agenda
# - what is variable?
# - creating variables
# - naming the variables
# - packing and unpacking
# - print,id,type,len,input functions
# - interview questions

# %% [markdown]
# ## What is variable?
# Python Variable is containers that store values. Python is not “statically typed”. We do not need to declare variables before using them or declare their type. A variable is created the moment we first assign a value to it. A Python variable is a name given to a memory location. It is the basic unit of storage in a program.

# %% [markdown]
# ### syntax :-   name of the variable= data to store(values)

# %% [markdown]
# ![var.png](attachment:var.png)

# %% [markdown]
# ## creating variables

# %%
student_count=1000 # int or whole numberes
print(student_count)
# Out:
# 1000

# %%
rating=4.9 #float 
print(rating)
# Out:
# 4.9

# %%
is_it_good_or_bad='yes it is good' # string
print(is_it_good_or_bad)
# Out:
# yes it is good

# %%
is_published=True 
print(is_published)
# Out:
# True

# %% [markdown]
# ## Naming the variables
# A variable can have a short name (like x and y) or a more descriptive name (age, carname, total_volume). Rules for Python variables:
#
#     A variable name must start with a letter or the underscore character
#     A variable name cannot start with a number
#     A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
#     Variable names are case-sensitive (age, Age and AGE are three different variables)
#     A variable name cannot be any of the Python keywords.

# %%
#rule 1

# %%
name=5
print(name)
# Out:
# 5

# %%
_name='techcodio'
print(_name)
# Out:
# techcodio

# %%
#rule 2

# %%
9name='balu'
print(9name)
# Out:
#   Cell In[25], line 1
#     9name='balu'
#     ^
# SyntaxError: invalid decimal literal

# %%
#rule 3
name_1='yes'
print(name_1)
# Out:
# yes

# %%
#rule 4

# %%
if='python'
print(if)
# Out:
#   Cell In[28], line 1
#     if='python'
#       ^
# SyntaxError: invalid syntax

# %%
+name='tete'
print(+name)
# Out:
#   Cell In[29], line 1
#     +name='tete'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# ## packing
# assigning more than 1 value to the vairable or assigning one value to more than 1 variable

# %%
var=1,2,3,4,5
print(var)
# Out:
# (1, 2, 3, 4, 5)

# %%
names='c','c++','python'
print(names)
# Out:
# ('c', 'c++', 'python')

# %% [markdown]
# ## upacking
# - If you have a collection of values in a list, tuple etc. Python allows you to extract the values into variables. This is called unpacking.
#  or
# - assigning more than one variable

# %%
a,b=1,2

# %%
print(a)
# Out:
# 1

# %%
print(b)
# Out:
# 2

# %%
a,b,c,d=[1,2,3,4]

# %%
a
# Out:
# 1

# %%
print(b)
# Out:
# 2

# %%
print(c)
# Out:
# 3

# %%
print(d)
# Out:
# 4

# %% [markdown]
# ## print()   (output function)
# The print() function prints the specified message to the screen, or other standard output device.
# The message can be a string, or any other object, the object will be converted into a string before written to the screen.

# %%
print('hello world')
# Out:
# hello world

# %%
var=4
print(var)
# Out:
# 4

# %% [markdown]
# ## type()
# used to know the type of the varaible or fuctions

# %%
a=4
b=4.8
c='yes'
d=True

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
ty

# %% [markdown]
# ## id()
# The id() function returns a unique id for the specified object.
#
# All objects in Python has its own unique id.
#
# The id is assigned to the object when it is created.
#
# The id is the object's memory address, and will be different for each time you run the program. (except for some object that has a constant unique id, like integers from -5 to 256)

# %%
a=4
id(a)
# Out:
# 140716683465608

# %%
b=6
id(b)
# Out:
# 140716683465672

# %% [markdown]
# ## len()
# used to find the length of a string,tuple,list,set,dictionary

# %%
var='python'
len(var)
# Out:
# 6

# %%
var1=' programming'
len(var1)
# Out:
# 12

# %% [markdown]
# ## input()
# Python input() function is used to take user input. By default, it returns the user input in form of a string.

# %%
var=input()
# Out:
# 22

# %%
print(var)
# Out:
# 22

# %%
type(var)
# Out:
# str

# %%
var1=input('Enter your name:')
# Out:
# Enter your name:bharath

# %%
print(var1)
# Out:
# bharath

# %%
type(var1)
# Out:
# str

# %% [markdown]
# ## interview questions

# %% [markdown]
# ## which of the following statements are correct?
# #### a.variable name can start with digit?
# #### b.variable name should not start with digit?
# #### c.vairable name should start with letter or underscore?
# #### d. none of the above

# %%
# option c is correct

# %% [markdown]
# ## what will be the output of the code?
# #### x=10
# #### y=20
# #### x,y=y,x
# #### print(x,y)

# %%
x=10
y=20

# %%
x,y=y,x

# %%
print(x,y)
# Out:
# 20 10

# %% [markdown]
# ## which symbol is used to begin the variable name?
# #### *
# #### +
# #### =
# #### _

# %%
# underscore symbol is used to begin the variable name

# %% [markdown]
# # variables in python

# %%
# it is a container it stores the data

# %%
var=2
var
# Out:
# 2

# %%
type(var)
# Out:
# int

# %%
var2=3.4
var
# Out:
# 2

# %%
var1='string'
var1
# Out:
# 'string'

# %% [markdown]
# # rules for naming variables

# %%
# 1.start a variable name with underscore or a letter
# 2. you cannot start variable name with symbols and digits
