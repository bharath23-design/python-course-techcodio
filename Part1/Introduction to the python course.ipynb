# %% [markdown]
# # PYTHON COURSE STRUCTURE
# ## It contains 8 parts
# ## Part 1 to Part 4 is Basic python
# ## Part 5 to Part 8 is Advanced python
# ## 5 projects

# %% [markdown]
# ## Part 1: Introduction to Python
#  - Python's historyand features
#  - Installing Python and setting up the development environment
#  - Running Python programs using an IDE or command line
#  - Setting the jupyter notebook environment

# %% [markdown]
# ## Part 2: Python Basics
# - print ,type,id,len,input
# - Variables
# - packing and unpacking
# - Expressions and Statements
# - Comments
# - Escaping Characters
# - Data types
#
# - casting
# - Operators
# - Strings
# - String Methods
#
# - String Characters & Slicing
# - Control Statements
# - break,continue,pass
# - Loops

# %% [markdown]
# ##  Project 1:  Pig game ( on If esle and loops)

# %% [markdown]
# ![pig%20game.png](attachment:pig%20game.png)

# %% [markdown]
# ## Part 3 : Functions and Modules:
# - Creating and calling functions
# - Function parameters and return values,nested functions
# - Modules and importing in Python
# - Using built-in modules and creating custom modules
# - built-in functions

# %% [markdown]
# ##  Project 2: Timed Math Challenge (on functions )

# %% [markdown]
# ## Part 4: Data Structures
# - Lists
# - list methods
# - slicing ,indexing and iterating
# - tuples
# - sets
# - set methods
# - dictionaries
# - dictionarie methods
# - list comprehensions
# - dictionary compreshensions

# %% [markdown]
# ##  Project 3: Word dictionary(using dictionaries)

# %% [markdown]
# ![word%20dict.png](attachment:word%20dict.png)

# %% [markdown]
# ## Part 5:File Handling:
# - Reading from and writing to files
# - File modes and handling exceptions
# - Working with CSV and JSON files

# %% [markdown]
# ##  Project 4: Creating file manager (using python)

# %% [markdown]
# ![file%20manger.png](attachment:file%20manger.png)

# %% [markdown]
# ## Part 6:Object-Oriented Programming (OOP)
# - Classes, objects, and instances
# - Inheritance
# - polymorphism ,Encapsulation and abstraction
# - pickling and unpickling

# %% [markdown]
# ##  project 5: Banking system (using oops concepts)

# %% [markdown]
# ![bankling.png](attachment:bankling.png)

# %% [markdown]
# ## Part 7: Exception Handling:
# - Handling and raising exceptions
# - Using try-except blocks and handling specific exceptions
# - Clean-up actions with finally block

# %% [markdown]
# ## Part 8:Functional Programming
# - lambda funtions
# - map(),filter(),reduce()

# %% [markdown]
# ## Most asked important programs for interview  preparation

# %% [markdown]
# ## Interview preparation ,resume building and job applying

# %% [markdown]
# ![done.png](attachment:done.png)

# %% [markdown]
# ## Duration of the course 2- 3 months
