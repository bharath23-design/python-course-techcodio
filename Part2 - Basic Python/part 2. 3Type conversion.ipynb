# %% [markdown]
# ###### Agenda
# ## what is type conversion?
# ## types of type conversion
# ## logical questions

# %% [markdown]
# ## what is type conversion
# Python defines type conversion functions to directly convert one data type to another which is useful in day-to-day and competitive programming.

# %% [markdown]
# ## Types of type conversion
# There are two types of Type Conversion in Python:
#
#     Implicit Type Conversion
#     Explicit Type Conversion
#
# Let’s discuss them in detail.

# %% [markdown]
# Implicit Type Conversion
#
# In Implicit type conversion of data types in Python, the Python interpreter automatically converts one data type to another without any user involvement. To get a more clear view of the topic see the below examples.

# %%
x = 10
print("x is of type:",type(x))
y = 10.6
print("y is of type:",type(y))
z = x + y
print(z)
print("z is of type:",type(z))
# Out:
# x is of type: <class 'int'>
# y is of type: <class 'float'>
# 20.6
# z is of type: <class 'float'>

# %% [markdown]
# Explicit Type Conversion
#
# In Explicit Type Conversion in Python, the data type is manually changed by the user as per their requirement. With explicit type conversion,
#
# - int()
# - float()
# - complex()
# - str()
# - chr()
# - ord()
#
# - lets discuss list(),tuple(),set(),dict() in advanced python

# %% [markdown]
# ### int(a,base) = converts any int,float,string values to int

# %% [markdown]
# ![float.png](attachment:float.png)

# %%
var=10.9
var1=int(var)
print(var1)
type(var1)
# Out:
# 10
# int

# %%
a='3'
int(a)
# Out:
# 3

# %% [markdown]
# ### float() =convert float,int ,stringto float values
# ![str.png](attachment:str.png)

# %%
a=4
b=float(a)
print(b)
type(b)
# Out:
# 4.0
# float

# %%
str_='10.9'
str_1=float(str_)
print(str_1)
type(str_1)
# Out:
# 10.9
# float

# %% [markdown]
# ### complex(real,imaginary) = converts complex,float,int,string to complex value

# %%
a=10
type(complex(a))
# Out:
# complex

# %%
b=6.7
complex(b)
# Out:
# (6.7+0j)

# %%
c='4.0'
complex(c)
# Out:
# (4+0j)

# %%
d='4.'
complex(d)
# Out:
# (4+0j)

# %% [markdown]
# ### str() converts any number,float,int,complex,str to string
# ![string.png](attachment:string.png)

# %%
a=7
type(str(a))
# Out:
# str

# %%
b=6.7
type(str(b))
# Out:
# str

# %%
c=4+5j
type(str(c))
# Out:
# str

# %% [markdown]
# ### chr(number): This function converts number to its corresponding ASCII character.
# American Standard Code for Information Interchange

# %%
a=chr(65)
type(a)
# Out:
# str

# %%
# 65 to 90
#A-Z

# %%
chr(90)
# Out:
# 'Z'

# %%
# for smaller case letter  97 to 122 a to z

# %%
chr(97)
# Out:
# 'a'

# %%
chr(122)
# Out:
# 'z'

# %%
chr(41)
# Out:
# ')'

# %% [markdown]
# ### ord() : It converts the given string of length one, returns an integer representing the Unicode code point of the character.
#
# American Standard Code for Information Interchange

# %%
ord('A')
# Out:
# 65

# %%
ord('a')
# Out:
# 97

# %%
ord('(')
# Out:
# 40

# %% [markdown]
# ## What is the output of the code complex('python') ?
# ## a . python + 0j
# ## b . value error
# ## c .0
# ## d . no output

# %%
complex('python')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 complex('python')
#
# ValueError: complex() arg is a malformed string

# %% [markdown]
# ## which function is used to give asci value when  I pass number?
# ## a. chr()
# ## b. Chr()
# ## c. odr()
# ## d. Ord()

# %%
Chr(65)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 Chr(65)
#
# NameError: name 'Chr' is not defined

# %%
chr(65)
# Out:
# 'A'
